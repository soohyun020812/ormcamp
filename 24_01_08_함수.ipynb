# %% [markdown]
# ### 함수
# 특정 작업을 수행하는 코드 블록을 하나의 이름 아래로 모음
#
# 함수를 호출하여 코드블록을 실행할 수 있음
#
# 들여쓰기 4칸 또는 탭 키로 통일
#
# ### 정의
#
# def 키워드를 사용
#
# 함수의 이름을 적고 콜론 (:)을 붙임, 이를 통해 새로운 함수가 정의

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def test():
	x = 10
	y = 20
	print(x, y)

# %%
# 함수 정의
def my_function():
# def : 함수, my_function : 함수 이름 + () -> :

# %%
# 들여쓰기 - 스페이스바 4번 입력 (띄어쓰기)
def my_function(): #함수의 정의
    print('1') #함수의 본문 시작
    print('2')
    print('3') #함수의 본문
my_function() #함수의 호출
# Out:
# 1
# 2
# 3

# %%
def my_function():
    print('1')
    print('2')
print('3')

my_function()
# Out:
# 3
# 1
# 2

# %%
# 함수 사용 이유
def 부지매입():
    pass

def 설계도면작성():
    pass

def 인력모집():
    pass

def 벽돌쌓기():
    pass

def 지붕올리기():
    pass

# 코드 양이 많아도 재사용하는 것은 한 줄
# 실수를 줄일 수 있고 코드의 구조를 한 눈에 파악하기 수월

# %% [markdown]
# ### 간단한 함수 만들어보기
#
# ![image.png](data:image/png;base64,...)

# %%
'''
"함수 = 함수의 선언, 이름, 입력, 기능 및 연산, 출력, 호출"
-
def 함수명(입력):
    기능, 연산
    return
print("함수명()=", 호출)
'''

# ex
def function_name(x, y):
    z = x + y
    return z

print(f'function_name(10, 9) = {function_name(10, 9)}')
# Out:
# function_name(10, 9) = 19

# %% [markdown]
# - **선언**: **`def`**
#
#     함수는 **`def`** 키워드를 사용하여 선언됩니다.
#
# - **이름**: **`function_name`**
#
#     함수의 이름은 함수를 식별하는 데 사용되며, 일반 변수의 이름을 지정하는 규칙에 따릅니다. 이 이름을 사용하여 함수를 나중에 호출할 수 있습니다.
#
# - **입력**:  **`x, y`**는 **`function_name`**에서 사용할 변수, 매개변수(파라미터, parameter)
#
#     함수는 파라미터(parameter, 매개변수, 인자)를 통해 외부에서 들어온 아규먼트(argument, 인수)를 입력 받습니다. 이 파라미터는 함수 호출 시에 함께 전달한 10, 9를 각각 x, y로 받아들입니다. 모든 함수가 파라미터를 필요로 하는 것은 아닙니다. 파라미터가 없는 함수도 있으며, 이러한 함수는 괄호 안에 어떤 값도 받지 않습니다.
#
#     이 책에서는 매개변수와 인수라는 용어 대신 파라미터와 아규먼트로 원문 그대로 읽도록 하겠습니다.
#
# - **기능과 연산**: **`z = x + y`**는 **`function`**의 내부에서 수행되는 연산
#
#     함수 본문에서는 다양한 연산과 처리 과정을 수행할 수 있습니다. 이 부분에서 변수에 값을 할당하거나, 데이터 구조를 조작하는 등의 작업을 수행합니다.
#
#     함수의 범위는 4칸 들여쓰기 된 곳까지 입니다. 만약 4칸 들여쓰기가 되어있지 않다면 해당 코드는 함수 바깥에 있는 코드입니다. 반드시 한 줄은 명시를 해야 합니다. 아무 코드를 넣지 않은 경우에는 pass 키워드를 넣어 애러가 나지 않게 합니다. 보통 함수의 골격을 잡을 때 pass 키워드를 사용합니다.
#
# - **출력(return)**: **`return z`**는 **`function`**에서 **`z`**의 값을 반환 (print문 값을 출력!)
#
#     **`return`** 키워드는 함수에서 특정 값을 반환하는 데 사용됩니다. 반환이라는 용어가 생소하실 수 있는데 함수가 호출된 곳에 들어갈 값입니다. 예를 들어 add(2, 3)의 반환 값이 5라면 add(2, 3)이 있던 자리에 5가 들어가는 것입니다. 반환 값을 지정하지 않으면 함수는 자동으로 **`None`**을 반환합니다. (함수를 호출하면 return으로 지정된 값을 불러온다.)
#
# - **호출**: `function_name(10, 9)`로 함수 호출
#
#     함수를 선언한 후에는 그 함수를 호출하여 실행해야 합니다. 함수의 호출은 함수 이름과 소괄호를 사용하여 수행되며, 아규먼트를 함수의 파라미터로 전달합니다.
#
#     함수는 호출되지 않으면 실행되지 않습니다. 아래 코드는 함수 내에 0으로 나누는 error가 있지만 호출이 되지 않았기 때문에 error가 나지 않습니다.

# %%
def function_name(x, y):
    pass #임시로 값을 넣는 기능!

# %%
def function_name(x, y):
    return x + y

function_name(10, 9)
# Out:
# 19

# %%
# 입력 매개변수가 없고, 반환 값도 없는 함수

def simple_function():
    print('Hello World')

# 함수 호출
print(simple_function())
# Out:
# Hello World
# None

# %% [markdown]
# - **함수의 선언:** **`def`** 키워드를 사용하여 **`simple_function`**이라는 함수를 선언했습니다. 이 함수는 파라미터가 없습니다.
# - **함수의 이름:** **`simple_function`**입니다.
# - **함수의 기능과 연산:** 함수 내부에서 ‘Hello, World!’라는 문자열을 출력합니다.
# - **함수의 출력(return):** 이 함수는 반환 값이 없습니다. 자동으로 None이 들어갑니다.
# - **함수의 호출:** **`simple_function()`**을 통해 함수를 호출하며, 아규먼트는 없습니다. 결과적으로 함수의 반환값인 None이 들어와 출력됩니다. 여기서 주의해야 할 것은 print는 함수의 반환값이 아니라는 것입니다. 추가로 colab에서는 마지막 라인 값을 print를 하지 않아도 출력하지만 None 값은 print를 하지 않으면 그 아래 라인에 출력되지 않습니다.

# %%
# 파라미터가 없고, 반환 값은 있는 함수

def give_me_five():
    return 5

result = give_me_five()
print(result) # 출력: 5
# Out:
# 5

# %% [markdown]
# - **함수의 선언:** **`def`** 키워드를 사용하여 **`give_me_five`**라는 함수를 선언했습니다. 이 함수는 파라미터가 선언되어 있지 않습니다.
# - **함수의 이름:** **`give_me_five`**입니다.
# - **함수의 기능과 연산:** 이 함수는 별도의 연산이 없습니다.
# - **함수의 출력(return):** **`5`**라는 값을 반환합니다.
# - **함수의 호출:** **`give_me_five()`**을 통해 함수를 호출합니다. 아규먼트는 없습니다.
#
# 이 예에서 **`give_me_five`** 함수는 정수 5를 반환합니다. 함수가 어떤 값을 계산하거나, 외부에서 어떤 값을 받지 않도록 설계된 경우 이렇게 할 수 있습니다.

# %%
def f():
    print(1 / 0)

print('hello')
# Out:
# hello

# %%
# 입력 매개변수가 있고, 반환 값이 없는 함수

def greeting(name):
    print(f'Hello, {name}!')

# 함수 호출
print(greeting('Licat'))
# Out:
# Hello, Licat!
# None

# %% [markdown]
# - **함수의 선언:** `def` 키워드를 사용하여 `greeting`이라는 함수를 선언했습니다. 이 함수는 `name`이라는 파라미터가 있습니다.
# - **함수의 이름:** `greeting`입니다.
# - **함수의 기능과 연산:** 함수 내부에서 받은 **`name`**을 사용하여 인사 메시지를 출력합니다.
# - **함수의 출력(return):** 이 함수는 반환 값이 없습니다.
# - **함수의 호출:** `greeting('Licat')`을 통해 함수를 호출하며, ‘Licat’이라는 아규먼트를 파라미터로 전달합니다.

# %%
# 입력 매개변수가 있고, 반환 값이 있는 함수

def add_numbers(x, y):
    sum = x + y
    return sum

# 함수 호출
result = add_numbers(5, 3)
print(result)
# Out:
# 8

# %% [markdown]
# - **함수의 선언:** **`def`** 키워드를 사용하여 **`add_numbers`**라는 함수를 선언했습니다. 이 함수는 **`x`**와 **`y`**라는 두 개의 파라미터가 있습니다.
# - **함수의 이름:** **`add_numbers`**입니다.
# - **함수의 기능과 연산:** 함수 내부에서 **`x`**와 **`y`**의 합을 계산하고, 그 결과를 **`sum`**이라는 변수에 저장합니다.
# - **함수의 출력(return):** **`sum`** 변수의 값을 반환합니다.
# - **함수의 호출:** **`add_numbers(5, 3)`**을 통해 함수를 호출하며, 5와 3 아규먼트를 파라미터로 전달합니다.
#
# 지금까지 함수의 기본적인 구성 요소와 작동 방식에 대해 알아보았습니다. 다양한 매개변수와 반환 값 등을 사용하여 함수를 어떻게 생성하고 사용하는지를 배웠습니다.

# %%
# print와 return 구분

def function(x, y):
    z = x + y
    print(z)
print(f'function(5, 7) = {function(5, 7)}')
# Out:
# 12
# function(5, 7) = None

# %%
print(print('hello'))
# Out:
# hello
# None

# %% [markdown]
# ### 함수의 아규먼트와 파라미터
#
# 아규먼트(argument)와 파라미터(parameter)는 프로그래밍에서 함수를 정의하고 호출할 때 쓰임
#
# - 파라미터 (Parameter)
#     - 함수를 정의할 때 사용되는 변수, 함수가 호출될 때 들어온 값을 변수에 할당
#
# - 아규먼트 (Argument)
#     - 함수를 호출할 때 전달하는 실제 값, 함수 호출 시 파라미터에 할당

# %%
def my_function(x, y):
    return x + y

# x와 y는 파라미터

# %%
result = my_function(5, 3)

# 5와 3은 아규먼트

# %%
# 파라미터의 기본 사용

def f(a, b, c):
    print(a, b, c)

f(a=100, b=200, c=300)
f(b=200, a=100, c=300)
f(c=300, a=100, b=200)
# Out:
# 100 200 300
# 100 200 300
# 100 200 300

# %%
# 기본값을 가진 파라미터

def f(a=10, b=20, c=30):
    print(a, b, c)

f() # 출력: 10 20 30
f(100, 10) # 출력: 100 10 30
f(a=100, b=200, c=300) # 출력: 100 200 300
f(c=300, a=100, b=200) # 출력: 100 200 300
# Out:
# 10 20 30
# 100 10 30
# 100 200 300
# 100 200 300

# %%
# 일부 파라미터만 기본값을 가지는 경우 (잘못된 예)

def f(a=10, b=20, c):
    print(a, b, c) # error
# Out:
#   File "<ipython-input-17-e2a8dbe8714d>", line 3
#     def f(a=10, b=20, c):
#                       ^
# SyntaxError: non-default argument follows default argument

# %%
# 일부 파라미터만 기본값을 가지는 경우 (올바른 예)

def f(a, b=20, c=10):
    print(a, b, c)

f(100, 10) # 출력: 100 10 10
f(a=100, b=200, c=300) # 출력: 100 200 300
f(c=300, a=100, b=200) # 출력: 100 200 300

# a는 기본값이 없음, 기본값이 없는 파라미터는 반드시 값을 전달해야 함
# Out:
# 100 10 10
# 100 200 300
# 100 200 300

# %%
# a는 파라미터에 기본값 없고 b와 c에는 기본값이 설정
# 함수 호출 시 a는 값을 반드시 전달해야 함

def f(a, b=20, c=30):
    print(a, b, c)

# print(f()) # error
print(f(100, 10)) # 출력 : 100, 10, 30
print(f(a=100, b=200, c=300)) # 출력 : 100 200 300
print(f(c=300, a=100, b=200)) # 출력 : 100 200 300
# print(f(c=300)) # error
# Out:
# 100 10 30
# None
# 100 200 300
# None
# 100 200 300
# None

# %%
# 컨밴션 자료형을 아규먼트로 넣었을 때

def add_element(my_list):
    my_list.append(1)

a = [2, 3, 4]
add_element(a)
print(a)  # 출력: [2, 3, 4, 1]
# Out:
# [2, 3, 4, 1]

# %%
def add_element(my_list):
    my_list.append(1)
    print(id(my_list)) # 출력: 135115033605760

a = [2, 3, 4]
add_element(a)
print(id(a)) # 출력: 135115033605760
print(a)  # 출력: [2, 3, 4, 1]
# Out:
# 133536858244352
# 133536858244352
# [2, 3, 4, 1]

# %%
def add_element(my_list):
    my_list = 10
    print(id(my_list)) # 출력: 135115442078224

a = [2, 3, 4]
add_element(a)
print(id(a)) # 출력: 135115029248768
print(a)  # 출력: [2, 3, 4]
# Out:
# 133537285849616
# 133536873172672
# [2, 3, 4]

# %%
# 권장하지 않는 기본값

# 권장하지 않는 방법
def append_to_list(value, lst=[]):
    lst.append(value)
    return lst # 예상치 못한 결과가 발생할 수 있습니다.

# lst=[]라는 기본값은 함수가 정의될 때 한 번만 생성되고, 같은 리스트 객체가 모든 함수 호출에 대해 공유
# 리스트가 변경될 때마다 (함수가 호출될 때마다) 변경된 내용이 유지되고 이는 다음과 같은 예상치 못한 결과를 초래할 수 있음

# %%
# 권장 방법
def append_to_list(value, lst=None):
    if lst is None:
        lst = []
    lst.append(value)
    return lst

# lst 파라미터의 기본값을 None으로 설정하고, 함수 본문 내에서 None 값을 새로운 리스트로 바꾸어 주어, 함수 호출 사이에 리스트가 공유되지 않도록 함
# 함수 호출이 독립적인 리스트를 가지게 되므로 예상치 못한 부작용 피할 수 있음

# %%
append_to_list(1)
append_to_list(2)
# Out:
# [2]
